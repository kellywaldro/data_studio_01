# %%
import os
import requests
import time

from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
api_key = os.getenv('key')

# %%
api_key
# Out:
# 'AIzaSyAhvN-XmekqD_DpyZo8hJvHqNkC5krC_cU'

# %%
import requests

url = f"https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=40.798841%2C-73.952014&radius=40000&keyword=pharmacy&key={api_key}"

payload={}
headers = {}

response = requests.request("GET", url, headers=headers, data=payload)

print(response.text)
# Out:
# {
#    "html_attributions" : [],
#    "next_page_token" : "AfLeUgN781Y1ZWI9JNst-m7SNWCvqq0Vtm9qLNBzf7bZHax5JZw5G80895qErKj7VdcJxI584Aq-kEPFRbZQxrUclPV9sT6kceNnR3pwU6pLhZlUAzS_KvAMr2VUQkw9VfxREj0YhwCllWeehaofAl0AHir_GOAW680quPwBSpZAOQIx-3Tuy9GPfaZsvBGDR2nZ-xh8Na268SpNJ87Hurwlu84_ZKIpQbmUkz01bbrBwtfgqsowi8jF71BFv10V5IiaaeqRhTSYFcJPXRcKpJqMk8JfWjIR9uA8wejqJVRGerky9emtnLJVsEJIRGmZkgRbyj3_R0ydI6tldtQjWG7QV2DHi6x2kvZYlx2a_XA2lp3pQ5wOoOkNJowhIBJTLziWZfuOrUxZrHabfQ9S2bMMsk2ZXQonLLuOoGqsRGfWtDCto5bBW_L_zsbhLw",
#    "results" : [
#       {
#          "business_status" : "OPERATIONAL",
#          "geometry" : {
#             "location" : {
#                "lat" : 40.7565939,
#                "lng" : -73.8783375
#             },
#             "viewport" : {
#                "northeast" : {
#                   "lat" : 40.75802252989272,
#                   "lng" : -73.87700102010727
#                },
#                "southwest" : {
#                   "lat" : 40.75532287010727,
# ...

# %%
len(payload)
# Out:
# 0
